# %%
# !CUDA_VISIBLE_DEVICES=5 python3 -W ignore main_al.py --coarse_sampling random
# Out:
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.
# Python version  3.7.6 (default, Jan  8 2020, 19:59:22)
# [GCC 7.3.0]
# PyTorch version  1.10.0+cu102
# Current dir: /storage/lzliao/NER_BERT_CRF
# Cuda is available? True
# Device: cuda:0
# len_label_list:  6
# label_map:  {'X': 0, '[CLS]': 1, '[SEP]': 2, 'O': 3, 'I': 4, 'B': 5}
# ...
# 100%|███████████████████████████████████████| 1433/1433 [08:31<00:00,  2.80it/s]
# Traceback (most recent call last):
#   File "main_al.py", line 154, in <module>
#     sampler = RandomSampling(args, tagging_model, labeled_data, unlabeled_data, label_map)
#   File "/storage/lzliao/NER_BERT_CRF/strategy_goal.py", line 302, in query
#     return random.sample(self.unlabeled_data, n)
#   File "/storage/lzliao/anaconda3/lib/python3.7/random.py", line 321, in sample
#     raise ValueError("Sample larger than population or is negative")
# ValueError: Sample larger than population or is negative
