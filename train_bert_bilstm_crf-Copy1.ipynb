# %%
# !CUDA_VISIBLE_DEVICES=7 python3 -W ignore NER_BERT_BILSTM_CRF_KB.py
# Out:
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.
# Python version  3.7.6 (default, Jan  8 2020, 19:59:22)
# [GCC 7.3.0]
# PyTorch version  1.10.0+cu102
# Current dir: /storage/lzliao/NER_BERT_CRF
# Cuda is available? True
# Device: cuda:0
# ***** Running training *****
#   Num examples = 25469
#   Batch size = 32
#   Num steps = 7959
# *** Use BertModel + BILSTM + CRF + KB***
# 100%|█████████████████████████████████████████| 796/796 [05:43<00:00,  2.32it/s]
# --------------------------------------------------------------
# Epoch:0 completed, Total training's Loss: 15650872.8671875, Spend: 5.728707512219747m
# before span
# after span
# Epoch:0, Acc:93.59, Precision: 81.46, Recall: 86.35, F1: 83.84, micro: 93.60, macro: 88.08, span-p: 72.30, span-r: 83.87, spanf1: 77.66 on Valid_set, Spend: 0.339 minutes for evaluation
# --------------------------------------------------------------
# ...

# %%
# !CUDA_VISIBLE_DEVICES=7 python3 -W ignore NER_BERT_BILSTM_CRF_KB.py
# Out:
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.
# Python version  3.7.6 (default, Jan  8 2020, 19:59:22)
# [GCC 7.3.0]
# PyTorch version  1.10.0+cu102
# Current dir: /storage/lzliao/NER_BERT_CRF
# Cuda is available? True
# Device: cuda:0
# ***** Running training *****
#   Num examples = 25469
#   Batch size = 32
#   Num steps = 7959
# *** Use BertModel + BILSTM + CRF + KB***
# 100%|█████████████████████████████████████████| 796/796 [05:43<00:00,  2.32it/s]
# --------------------------------------------------------------
# Epoch:0 completed, Total training's Loss: 15650795.3828125, Spend: 5.723386216163635m
# before span
# after span
# Epoch:0, Acc:93.48, Precision: 80.91, Recall: 86.52, F1: 83.62, micro: 93.48, macro: 87.92, span-p: 71.51, span-r: 84.05, spanf1: 77.27 on Valid_set, Spend: 0.338 minutes for evaluation
# --------------------------------------------------------------
# ...
